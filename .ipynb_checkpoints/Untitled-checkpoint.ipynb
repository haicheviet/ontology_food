# %%
Has_Nutrient = ["ssss", 'dddd']
list_line_nutrient = len(Has_Nutrient)
template = """    
<!-- http://www.co-ode.org/ontologies/ont.owl#{} -->

    <NamedIndividual rdf:about="&ont;{}">
        <rdf:type rdf:resource="&ont;{}"/>
        <ont:Has_calo rdf:datatype="&xsd;int">{}</ont:Has_calo>
        <ont:Has_processing rdf:datatype="&xsd;string">{}</ont:Has_processing>
        <ont:Has_suitable_time rdf:datatype="&xsd;string">{}</ont:Has_suitable_time>
    </NamedIndividual>
        \n\n\n""".format("Name_of_food", "Name_of_food", "Type_food", "Has_calo", "Has_processing", "Has_suitable_time")
for line in range(list_line_nutrient):
    line_nutrient = '    <ont:Has_Nutrient rdf:resource="&ont;{}"/>\n'.format(Has_Nutrient[line])
    index = template.find('</NamedIndividual>')
    template = template[:index] + line_nutrient + template[index:]
print(template)
# Out:
#
# <!-- http://www.co-ode.org/ontologies/ont.owl#Name_of_food -->
#
#     <NamedIndividual rdf:about="&ont;Name_of_food">
#         <rdf:type rdf:resource="&ont;Type_food"/>
#         <ont:Has_calo rdf:datatype="&xsd;int">Has_calo</ont:Has_calo>
#         <ont:Has_processing rdf:datatype="&xsd;string">Has_processing</ont:Has_processing>
#         <ont:Has_suitable_time rdf:datatype="&xsd;string">Has_suitable_time</ont:Has_suitable_time>
#         <ont:Has_Nutrient rdf:resource="&ont;ssss"/>
# 	    <ont:Has_Nutrient rdf:resource="&ont;dddd"/>
# 	</NamedIndividual>

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

sns.set_style("darkgrid")
plt.plot(np.cumsum(np.random.randn(1000,1)))
plt.title("Sample_")
plt.
plt.show()
